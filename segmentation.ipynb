# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import glob


img=cv2.imread(r"C:\Users\91966\Desktop\normal\Normal-1.png",0)
#plt.hist(img.flat,bins=100,range=(0,255)) #65> white


segm1=(img<=110)
segm2=(img>110)

all_segm=np.zeros((img.shape[0],img.shape[1],3))

all_segm[segm1]=(0,0,0)
all_segm[segm2]=(211,211,211)
    
    
plt.imshow(all_segm)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
